# %%
import pandas as pd
import seaborn as sns

# %%
dfalbum = pd.read_csv('dataset/albums.csv', sep=';')
dfrating = pd.read_csv('dataset/ratings.csv', sep=';')

# %%
print(dfalbum.duplicated().sum())
print(dfrating.duplicated().sum())
# Out:
# 0
# 0

# %%
print(dfalbum.columns)
print(dfrating.columns)
# Out:
# Index(['artis', 'link_artis', 'album', 'thumbnail_album', 'tracklist_album',
#        'link_review', 'tanggal_rilis', 'label', 'genre', 'produser', 'penulis',
#        'link_album', 'thumbnail_artis'],
#       dtype='object')
# Index(['link_album', 'user', 'rating_album', 'link_user'], dtype='object')

# %%
dfalbum
# Out:
#                        artis                          link_artis  \
# 0                   Yard Act              artist/86788-yard-act/
# 1                   Mile End             artist/192679-mile-end/
# 2                    J Dilla                 artist/448-j-dilla/
# 3              The Gathering          artist/3111-the-gathering/
# 4        Biking With Francis  artist/255468-biking-with-francis/
# ...                      ...                                 ...
# 4872  Freddie Gibbs & Madlib           artist/936-freddie-gibbs/
# 4873       Baco Exu Do Blues     artist/34832-baco-exu-do-blues/
# 4874                Big Sean               artist/1847-big-sean/
# 4875              Nick Lyons            artist/98351-nick-lyons/
# 4876                 mxmtoon               artist/55661-mxmtoon/
#
#                          album  \
# 0           Where's My Utopia?
# 1                     Mile End
# 2                       Donuts
# 3     How to Measure a Planet?
# ...

# %%
dfrating
# Out:
#                                               link_album         user  \
# 0         album/889060-st-vincent-all-born-screaming.php         Joko
# 1      album/867088-taylor-swift-the-tortured-poets-d...         Joko
# 2          album/870796-maggie-rogers-dont-forget-me.php         Joko
# 3      album/868936-vampire-weekend-only-god-was-abov...         Joko
# 4                 album/873803-beyonce-cowboy-carter.php         Joko
# ...                                                  ...          ...
# 11757             album/50635-charli-xcx-vroom-vroom.php  SnakeyWakey
# 11758                      album/16605-fka-twigs-lp1.php  SnakeyWakey
# 11759             album/14008-lykke-li-i-never-learn.php  SnakeyWakey
# 11760              album/11789-st-vincent-st-vincent.php  SnakeyWakey
# 11761             album/2068-lykke-li-wounded-rhymes.php  SnakeyWakey
#
#        rating_album          link_user
# 0               100         user/joko/
# 1               100         user/joko/
# ...

# %%
dfalbum.artis.value_counts().head(25)
# Out:
# artis
# Taylor Swift                        26
# Various Artists                     26
# Mac Miller                          25
# Kanye West                          18
# King Gizzard & The Lizard Wizard    16
# Madonna                             13
# Drake                               13
# Eminem                              12
# Swans                               12
# Björk                               12
# The Beatles                         11
# Charli XCX                          11
# Beyoncé                             11
# Kid Cudi                            11
# Tyler, The Creator                  11
# Lady Gaga                           10
# The Weeknd                          10
# Red Velvet                          10
# Death Grips                         10
# Lil Uzi Vert                        10
# Gorillaz                             9
# Lana Del Rey                         9
# Sufjan Stevens                       9
# Frank Ocean                          9
# ...

# %%
dfalbum.describe()
# Out:
#                artis               link_artis    album  \
# count           4877                     4849     4877
# unique          2745                     2619     4823
# top     Taylor Swift  artist/2442-mac-miller/  Visions
# freq              26                       31        4
#
#                                           thumbnail_album  \
# count                                                4758
# unique                                               4758
# top     https://cdn2.albumoftheyear.org/375x/album/778...
# freq                                                    1
#
#                                           tracklist_album  \
# count                                                3406
# unique                                               3398
# top     Spirit They've Vanished;|April and the Phantom...
# freq                                                    2
#
#                                               link_review  \
# ...

# %%
dfrating.describe()
# Out:
#        rating_album
# count  11762.000000
# mean      91.412175
# std       14.238258
# min        0.000000
# 25%       90.000000
# 50%       96.000000
# 75%      100.000000
# max      100.000000

# %%
sns.displot(data=dfrating, x='rating_album')
